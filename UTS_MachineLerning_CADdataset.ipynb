# %% [markdown]
# <a href="https://colab.research.google.com/github/suryarisa113/PRATIKUM-1-G.231.21.0045/blob/main/UTS_MachineLerning_CADdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb2d01eb-113d-4547-82fd-c5609b1e2bdd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb2d01eb-113d-4547-82fd-c5609b1e2bdd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('CADdataset.csv', sep='|', names=['col1'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    305 non-null    object
# dtypes: object(1)
# memory usage: 2.5+ KB

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# Length: 305, dtype: bool

# %%
data.head()
# Out:
#                                                 col1
# 0  Age,Weight,Height,Sex,BMI,DM,HTN,Current Smoke...
# 1  53,90,175,Male,29.3877551,0,1,1,Y,Y,110,N,0,N,...
# 2  67,70,157,Fmale,28.398718,0,1,0,Y,N,140,N,1,N,...
# 3  54,54,164,Male,20.07733492,0,0,1,N,N,100,N,1,N...
# 4  66,67,158,Fmale,26.83864765,0,1,0,Y,N,100,N,0,...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('col1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_4['col1'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_4, x='index', y='col1', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
